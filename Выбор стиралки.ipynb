# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df=pd.read_excel(f"Книга 36.xlsx")
df
# Out:
#                Название   Цена  Загрузка  Уровень шума max  \
# 0    DEXP WM-FM3SDWI/GG  23499       2.5                65
# 1  Бирюса WM-SM510/04 M  20050       5.0                74
# 2       Beko WRE55P1BSS  22240       5.0                78
# 3    Haier HW50-12866ME  18400       5.0                71
#
#    Расход воды за стирку Класс энергопотребления  Отзывы  Скорость при отжиме  \
# 0                   35.0                    A+++     4.6                  700
# 1                   54.0                     A++     5.0                 1000
# 2                   47.5                       A     4.8                 1000
# 3                   45.0                       A     3.9                 1200
#
#    Дозагрузка белья
# 0                 0
# 1                 1
# 2                 0
# 3                 0

# %%
df=df.loc[0:2]

# %%
sns.set_style("whitegrid")
ax=sns.barplot(df, x='Уровень шума max',y='Название')
ax.plot(68,0,"*", markersize=15, color="m")
plt.show()

# %%
ax=sns.barplot(df, x='Цена',y='Название')
ax.plot(21000,1,"*", markersize=15, color="m")
plt.show()

# %%
ax=sns.barplot(df, x='Отзывы',y='Название')
ax.plot(5.2,1,"*", markersize=15, color="m")
plt.show()

# %%
ax=sns.barplot(df, x='Скорость при отжиме',y='Название')
ax.plot(1040,1,"*", markersize=15, color="m")
ax.plot(1040,2,"*", markersize=15, color="m")
plt.show()

# %%
ax=sns.barplot(df, x='Расход воды за стирку',y='Название')
ax.plot(50.5,2,"*", markersize=15, color="m")
plt.show()

# %%
df
# Out:
#                Название   Цена  Загрузка  Уровень шума max  \
# 0    DEXP WM-FM3SDWI/GG  23499         5                65
# 1  Бирюса WM-SM510/04 M  20050         5                74
# 2       Beko WRE55P1BSS  22240         5                78
#
#    Расход воды за стирку Класс энергопотребления  Отзывы  Скорость при отжиме  \
# 0                     70                    A+++     4.6                  700
# 1                     54                     A++     5.0                 1000
# 2                     48                       A     4.8                 1000
#
#    Дозагрузка белья
# 0                 0
# 1                 1
# 2                 0
